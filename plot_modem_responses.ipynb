# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
from mtpy import MTData
from mtpy.modeling.plots.plot_model_responses import PlotResponse

# %%
data_fn = Path(r"c:\Users\jpeacock\OneDrive - DOI\ClearLake\modem_inv\clvf_tests\cl_modem_data_z03_t02_tec_11.dat")
resp_fn = Path(r"c:\Users\jpeacock\OneDrive - DOI\ClearLake\modem_inv\clvf_tests\clvf_z03_t02_c02_smavg_042.dat")

# %%
pr = PlotResponse(
        data_fn=data_fn,
        resp_fn=resp_fn,
        plot_style=1,
        fig_size=[9, 3.25],
        ms=2,
        subplot_bottom=0.12,
        subplot_left=0.05,
        font_size=5.7,
        plot_z=False,
        cted=(0, 0, 0),
        ctmd=(0, 0, 0),
        ctem=(0.75, 0.0, 0.0),
        ctmm=(0.75, 0.0, 0.0),
        mted="o",
        mtem="x",
        mtmm="x",
        subplot_wspace=0.20,
    )

# %%
pr.plot_station = "cl435"

# %%
pr.plot_tipper = True
p1 = pr.plot()
# Out:
# Plotting: cl435
# self.plot_tipper = True

# %%
sv_path = Path(r"c:\Users\jpeacock\OneDrive - DOI\ClearLake\jvgr_manuscript\Figures\supplemental")
for ss in [s.split("/")[-1] for s in pr.data_object.station_paths if "data" in s]:
    pr.plot_station = ss
    pr.plot_tipper = True
    pr.plot()
    pr.save_figure(
        save_fn=sv_path / f"Supp_{ss}.png",
        file_format=None,
        fig_dpi=300,
        close_fig=True,
    )
# Out:
# Plotting: 201
# self.plot_tipper = False
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 6
#       2 for ss in [s.split("/")[-1] for s in pr.data_object.station_paths if "data" in s]:
#       3     pr.plot_station = ss
#       4     pr.plot_tipper = True
#       5     pr.plot()
# ----> 6     pr.save_figure(
#       7         save_fn=sv_path / f"Supp_{ss}.png",
#       8         file_format=None,
#       9         fig_dpi=300,
#
# File ~\OneDrive - DOI\Documents\GitHub\mtpy-v2\mtpy\modeling\plots\plot_model_responses.py:33, in save_figure(self, save_fn, file_format, orientation, fig_dpi, close_fig)
#      28 class PlotResponse:
#      29     """Plot ModEM data and model responses.
#      30
#      31     ModEM data files are loaded into :class:`mtpy.MTData` using the ``data``
#      32     survey; model response files use the ``model`` survey.  This class keeps
# ---> 33     the existing plot styles while reading stations through the tree-backed
#      34     MTData API.
#      35
#      36     :Example: ::
#      37
#      38         >>> import mtpy.modeling.modem as modem
#      39         >>> dfn = r"/home/MT/ModEM/Inv1/DataFile.dat"
#      40         >>> rfn = r"/home/MT/ModEM/Inv1/Test_resp_000.dat"
#      41         >>> mrp = modem.PlotResponse(data_fn=dfn, resp_fn=rfn)
#      42         >>> # plot only the TE and TM modes
#      43         >>> mz_obj.plot_component = 2
#      44         >>> mz_obj.redraw_plot()
#      45
#      46     ======================== ==================================================
#      47     Attributes               Description
#      48     ======================== ==================================================
#      49     color_mode               [ 'color' | 'bw' ] color or black and white plots
#      50     cted                     color for data Z_XX and Z_XY mode
#      51     ctem                     color for model Z_XX and Z_XY mode
#      52     ctmd                     color for data Z_YX and Z_YY mode
#      53     ctmm                     color for model Z_YX and Z_YY mode
#      54     data_fn                  full path to data file
#      55     data_object              WSResponse instance
#      56     e_capsize                cap size of error bars in points (*default* is .5)
#      57     e_capthick               cap thickness of error bars in points (*default*
#      58                              is 1)
#      59     fig_dpi                  resolution of figure in dots-per-inch (300)
#      60     fig_list                 list of matplotlib.figure instances for plots
#      61     fig_size                 size of figure in inches (*default* is [6, 6])
#      62     font_size                size of font for tick labels, axes labels are
#      63                              font_size+2 (*default* is 7)
#      64     legend_border_axes_pad   padding between legend box and axes
#      65     legend_border_pad        padding between border of legend and symbols
#      66     legend_handle_text_pad   padding between text labels and symbols of legend
#      67     legend_label_spacing     padding between labels
#      68     legend_loc               location of legend
#      69     legend_marker_scale      scale of symbols in legend
#      70     lw                       line width data curves (*default* is .5)
#      71     ms                       size of markers (*default* is 1.5)
#      72     lw_r                     line width response curves (*default* is .5)
#      73     ms_r                     size of markers response curves (*default* is 1.5)
#      74     mted                     marker for data Z_XX and Z_XY mode
#      75     mtem                     marker for model Z_XX and Z_XY mode
#      76     mtmd                     marker for data Z_YX and Z_YY mode
#      77     mtmm                     marker for model Z_YX and Z_YY mode
#      78     phase_limits             limits of phase
#      79     plot_component           [ 2 | 4 ] 2 for TE and TM or 4 for all components
#      80     plot_style               [ 1 | 2 ] 1 to plot each mode in a seperate
#      81                              subplot and 2 to plot xx, xy and yx, yy in same
#      82                              plots
#      83     plot_type                [ '1' | list of station name ] '1' to plot all
#      84                              stations in data file or input a list of station
#      85                              names to plot if station_fn is input, otherwise
#      86                              input a list of integers associated with the
#      87                              index with in the data file, ie 2 for 2nd station
#      88     plot_z                   [ True | False ] *default* is True to plot
#      89                              impedance, False for plotting resistivity and
#      90                              phase
#      91     plot_yn                  [ 'n' | 'y' ] to plot on instantiation
#      92     res_limits               limits of resistivity in linear scale
#      93     resp_fn                  full path to response file
#      94     resp_object              WSResponse object for resp_fn, or list of
#      95                              WSResponse objects if resp_fn is a list of
#      96                              response files
#      97     station_fn               full path to station file written by WSStation
#      98     subplot_bottom           space between axes and bottom of figure
#      99     subplot_hspace           space between subplots in vertical direction
#     100     subplot_left             space between axes and left of figure
#     101     subplot_right            space between axes and right of figure
#     102     subplot_top              space between axes and top of figure
#     103     subplot_wspace           space between subplots in horizontal direction
#     104     ======================== ==================================================
#     105     """
#     107     def __init__(
#     108         self,
#     109         data_fn: str | Path | None = None,
#     110         resp_fn: str | Path | list[str | Path] | None = None,
#     111         **kwargs: Any,
#     112     ) -> None:
#     113         """Initialize a ModEM response plot.
#     114
#     115         Parameters
#    (...)    122             Plot appearance and layout options.
#     123         """
#
# TypeError: can only concatenate str (not "WindowsPath") to str

# %%
sv_path / f"{ss}.png"
# Out:
# WindowsPath('c:/Users/jpeacock/OneDrive - DOI/ClearLake/jvgr_manuscript/Figures/supplemental/201.png')
