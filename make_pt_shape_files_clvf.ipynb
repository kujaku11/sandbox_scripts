# %%
# %load_ext autoreload
# %autoreload 2

from mtpy import MTData

# %%
md = MTData()
md.from_modem(r"c:\Users\jpeacock\OneDrive - DOI\ClearLake\modem_inv\inv_05_topo\cl_modem_data_z03_t02_tec_11.dat")

# %%
md.to_shp_pt_tipper(
    r"c:\Users\jpeacock\OneDrive - DOI\ClearLake\modem_inv\inv_05_topo\phase_tensors", 
    output_crs=md.center_point.utm_crs, 
    utm=True, 
    ellipse_size=1800, 
    arrow_size=12000
    )
# Out:
# 26:02:17T13:25:48 | INFO | line:308 |mtpy.gis.shapefile_creator | _export_shapefiles | Saved shapefile to c:\Users\jpeacock\OneDrive - DOI\ClearLake\modem_inv\inv_05_topo\phase_tensors\Phase_Tensor_EPSG_32610_Period_0.00333333s.shp
# 26:02:17T13:25:48 | INFO | line:308 |mtpy.gis.shapefile_creator | _export_shapefiles | Saved shapefile to c:\Users\jpeacock\OneDrive - DOI\ClearLake\modem_inv\inv_05_topo\phase_tensors\Tipper_Real_EPSG_32610_Period_0.00333333s.shp
# 26:02:17T13:25:48 | INFO | line:308 |mtpy.gis.shapefile_creator | _export_shapefiles | Saved shapefile to c:\Users\jpeacock\OneDrive - DOI\ClearLake\modem_inv\inv_05_topo\phase_tensors\Tipper_Imag_EPSG_32610_Period_0.00333333s.shp
# 26:02:17T13:25:48 | INFO | line:308 |mtpy.gis.shapefile_creator | _export_shapefiles | Saved shapefile to c:\Users\jpeacock\OneDrive - DOI\ClearLake\modem_inv\inv_05_topo\phase_tensors\Phase_Tensor_EPSG_32610_Period_0.00610928s.shp
# ...

# %%
ptm = md.plot_phase_tensor_map(
    plot_period=100,
    ellipse_size=0.025,
    plot_tipper="yri",
    arrow_size=0.1,
    arrow_head_width=0.005,
    x_pad=0.05,
    y_pad=0.05,
    arrow_direction=1,
)
# Out:
# 26:02:17T13:10:57 | WARNING | line:784 |mtpy.imaging.plot_phase_tensor_maps | plot | Could not add base map because HTTPSConnectionPool(host='basemap.nationalmap.gov', port=443): Max retries exceeded with url: /arcgis/rest/services/USGSTopo/MapServer/tile/10/389/161 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1032)')))
